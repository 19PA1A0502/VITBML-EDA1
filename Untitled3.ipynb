# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0502/VITBML-EDA1/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **THE DATA IS ABOUT** **RAINS IN AUSTRAILIA**
# **Exploring Data:** we took data from online source: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package this data set contains:142193 rows and 24 columns
#
# The Variables in the data set are:
#
#
# Date:The date of observation
#
# Location:The common name of the location of the weather station
#
# MinTemp:The minimum temperature in degrees celsius
#
# MaxTemp:The maximum temperature in degrees celsius
#
# Rainfall:The amount of rainfall recorded for the day in mm:
#
# Evaporation:The so-called Class A pan evaporation (mm) in the 24 hours to 9am
#
# Sunshine:The number of hours of bright sunshine in the day.
#
# WindGustDir:The direction of the strongest wind gust in the 24 hours to midnight
#
# WindGustSpeed:The speed (km/h) of the strongest wind gust in the 24 hours to mid night
#
# WindDir9am:Direction of the wind at 9am
#
# WindDir3pm:Direction of the wind at 3pm
#
# WindSpeed9am:Wind speed (km/hr) averaged over 10 minutes prior to 9am
#
# WindSpeed3pm:Wind speed (km/hr) averaged over 10 minutes prior to 3pm
#
# Humidity9am:Humidity (percent) at 9am
#
# Humidity3pm:Humidity (percent) at 3pm
#
# Pressure9am:Atmospheric pressure (hpa) reduced to mean sea level at 9am
#
# Pressure3pm:Atmospheric pressure (hpa) reduced to mean sea level at 3pm
#
# Cloud9am:Fraction of sky obscured by cloud at 9am. This is measured in "oktas", which are a unit of eigths. It records how many eigths of the sky are obscured by cloud. A 0 measure indicates completely clear sky whilst an 8 indicates that it is completely overcast
# of sky obscured
#
#  Cloud3pm:fraction by cloud (in "oktas": eighths) at 3pm. See Cload9am for a description of the values
#
# Temp9am:Temperature (degrees C) at 9am
#
# Temp3pm:Temperature (degrees C) at 3pm
#
# RainTodayBoolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
#
# RISK_MM:The amount of next day rain in mm. Used to create response variable RainTomorrow. A kind of measure of the "risk".
#
#
# RainTomorrow:The target variable. Did it rain tomorrow

# %% [markdown]
# questions:
# 1.  what is the  maximum temperature recordedin degrees
# celsius?
# 2.   what is the maximum amount of rainfall recorded in a day?
# 1.  maximum number of sunshine during a day?
# 2. To get  idea on what type of data is this?
# 1.   what is the minimum temperature recorded in celsius from the given dataset?
# 2.   in which direction  maximum strongest wind blows?
# 1. in which direction wind speed in 9am will be occured most ?

# %%
import pandas as pd
a=pd.read_csv('weather-dataset-rattle-package.zip')
a
# Out:
#               Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0       2008-12-01   Albury     13.4  ...         No      0.0            No
# 1       2008-12-02   Albury      7.4  ...         No      0.0            No
# 2       2008-12-03   Albury     12.9  ...         No      0.0            No
# 3       2008-12-04   Albury      9.2  ...         No      1.0            No
# 4       2008-12-05   Albury     17.5  ...         No      0.2            No
# ...            ...      ...      ...  ...        ...      ...           ...
# 142188  2017-06-20    Uluru      3.5  ...         No      0.0            No
# 142189  2017-06-21    Uluru      2.8  ...         No      0.0            No
# 142190  2017-06-22    Uluru      3.6  ...         No      0.0            No
# 142191  2017-06-23    Uluru      5.4  ...         No      0.0            No
# 142192  2017-06-24    Uluru      7.8  ...         No      0.0            No
#
# [142193 rows x 24 columns]

# %%
a.shape
# Out:
# (142193, 24)

# %%
a.ndim
# Out:
# 2

# %%
a.head()
# Out:
#          Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...         No      0.0            No
# 1  2008-12-02   Albury      7.4  ...         No      0.0            No
# 2  2008-12-03   Albury     12.9  ...         No      0.0            No
# 3  2008-12-04   Albury      9.2  ...         No      1.0            No
# 4  2008-12-05   Albury     17.5  ...         No      0.2            No
#
# [5 rows x 24 columns]

# %%
a.head(10)
# Out:
#          Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...         No      0.0            No
# 1  2008-12-02   Albury      7.4  ...         No      0.0            No
# 2  2008-12-03   Albury     12.9  ...         No      0.0            No
# 3  2008-12-04   Albury      9.2  ...         No      1.0            No
# 4  2008-12-05   Albury     17.5  ...         No      0.2            No
# 5  2008-12-06   Albury     14.6  ...         No      0.0            No
# 6  2008-12-07   Albury     14.3  ...         No      0.0            No
# 7  2008-12-08   Albury      7.7  ...         No      0.0            No
# 8  2008-12-09   Albury      9.7  ...         No      1.4           Yes
# 9  2008-12-10   Albury     13.1  ...        Yes      0.0            No
#
# [10 rows x 24 columns]

# %%
a.tail()
# Out:
#               Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 142188  2017-06-20    Uluru      3.5  ...         No      0.0            No
# 142189  2017-06-21    Uluru      2.8  ...         No      0.0            No
# 142190  2017-06-22    Uluru      3.6  ...         No      0.0            No
# 142191  2017-06-23    Uluru      5.4  ...         No      0.0            No
# 142192  2017-06-24    Uluru      7.8  ...         No      0.0            No
#
# [5 rows x 24 columns]

# %%
a.tail(10)
# Out:
#               Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 142183  2017-06-15    Uluru      2.6  ...         No      0.0            No
# 142184  2017-06-16    Uluru      5.2  ...         No      0.0            No
# 142185  2017-06-17    Uluru      6.4  ...         No      0.0            No
# 142186  2017-06-18    Uluru      8.0  ...         No      0.0            No
# 142187  2017-06-19    Uluru      7.4  ...         No      0.0            No
# 142188  2017-06-20    Uluru      3.5  ...         No      0.0            No
# 142189  2017-06-21    Uluru      2.8  ...         No      0.0            No
# 142190  2017-06-22    Uluru      3.6  ...         No      0.0            No
# 142191  2017-06-23    Uluru      5.4  ...         No      0.0            No
# 142192  2017-06-24    Uluru      7.8  ...         No      0.0            No
#
# [10 rows x 24 columns]

# %%
a.count()
# Out:
# Date             142193
# Location         142193
# MinTemp          141556
# MaxTemp          141871
# Rainfall         140787
# Evaporation       81350
# Sunshine          74377
# WindGustDir      132863
# WindGustSpeed    132923
# WindDir9am       132180
# WindDir3pm       138415
# WindSpeed9am     140845
# WindSpeed3pm     139563
# Humidity9am      140419
# Humidity3pm      138583
# Pressure9am      128179
# Pressure3pm      128212
# Cloud9am          88536
# Cloud3pm          85099
# Temp9am          141289
# Temp3pm          139467
# RainToday        140787
# RISK_MM          142193
# RainTomorrow     142193
# dtype: int64

# %%
a.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
a.max()
# Out:
# Date             2017-06-25
# Location            Woomera
# MinTemp                33.9
# MaxTemp                48.1
# Rainfall                371
# Evaporation             145
# Sunshine               14.5
# WindGustSpeed           135
# WindSpeed9am            130
# WindSpeed3pm             87
# Humidity9am             100
# Humidity3pm             100
# Pressure9am            1041
# Pressure3pm          1039.6
# Cloud9am                  9
# Cloud3pm                  9
# Temp9am                40.2
# Temp3pm                46.7
# RISK_MM                 371
# RainTomorrow            Yes
# dtype: object

# %%
a.min()
# Out:
# Date             2007-11-01
# Location           Adelaide
# MinTemp                -8.5
# MaxTemp                -4.8
# Rainfall                  0
# Evaporation               0
# Sunshine                  0
# WindGustSpeed             6
# WindSpeed9am              0
# WindSpeed3pm              0
# Humidity9am               0
# Humidity3pm               0
# Pressure9am           980.5
# Pressure3pm           977.1
# Cloud9am                  0
# Cloud3pm                  0
# Temp9am                -7.2
# Temp3pm                -5.4
# RISK_MM                   0
# RainTomorrow             No
# dtype: object

# %%
a.std()
# Out:
# MinTemp           6.403283
# MaxTemp           7.117618
# Rainfall          8.465173
# Evaporation       4.188537
# Sunshine          3.781525
# WindGustSpeed    13.588801
# WindSpeed9am      8.893337
# WindSpeed3pm      8.803345
# Humidity9am      19.051293
# Humidity3pm      20.797772
# Pressure9am       7.105476
# Pressure3pm       7.036677
# Cloud9am          2.887016
# Cloud3pm          2.720633
# Temp9am           6.492838
# Temp3pm           6.937594
# RISK_MM           8.477969
# dtype: float64

# %%
a.mean()
# Out:
# MinTemp            12.186400
# MaxTemp            23.226784
# Rainfall            2.349974
# Evaporation         5.469824
# Sunshine            7.624853
# WindGustSpeed      39.984292
# WindSpeed9am       14.001988
# WindSpeed3pm       18.637576
# Humidity9am        68.843810
# Humidity3pm        51.482606
# Pressure9am      1017.653758
# Pressure3pm      1015.258204
# Cloud9am            4.437189
# Cloud3pm            4.503167
# Temp9am            16.987509
# Temp3pm            21.687235
# RISK_MM             2.360682
# dtype: float64

# %%
a.median()
# Out:
# MinTemp            12.0
# MaxTemp            22.6
# Rainfall            0.0
# Evaporation         4.8
# Sunshine            8.5
# WindGustSpeed      39.0
# WindSpeed9am       13.0
# WindSpeed3pm       19.0
# Humidity9am        70.0
# Humidity3pm        52.0
# Pressure9am      1017.6
# Pressure3pm      1015.2
# Cloud9am            5.0
# Cloud3pm            5.0
# Temp9am            16.7
# Temp3pm            21.1
# RISK_MM             0.0
# dtype: float64

# %%
a.mode()
# Out:
#            Date  Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0    2013-03-02  Canberra      9.6  ...         No      0.0            No
# 1    2013-03-03       NaN     11.0  ...        NaN      NaN           NaN
# 2    2013-03-04       NaN      NaN  ...        NaN      NaN           NaN
# 3    2013-03-06       NaN      NaN  ...        NaN      NaN           NaN
# 4    2013-03-07       NaN      NaN  ...        NaN      NaN           NaN
# ..          ...       ...      ...  ...        ...      ...           ...
# 457  2017-06-12       NaN      NaN  ...        NaN      NaN           NaN
# 458  2017-06-14       NaN      NaN  ...        NaN      NaN           NaN
# 459  2017-06-15       NaN      NaN  ...        NaN      NaN           NaN
# 460  2017-06-21       NaN      NaN  ...        NaN      NaN           NaN
# 461  2017-06-23       NaN      NaN  ...        NaN      NaN           NaN
#
# [462 rows x 24 columns]

# %%
# 1.
a['MaxTemp'].max()
# Out:
# 48.1

# %%
# 2.
a['Rainfall'].max()
# Out:
# 371.0

# %%
# 3.
a['Sunshine'].max()
# Out:
# 14.5

# %%
# 4.
a.head()
# Out:
#          Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...         No      0.0            No
# 1  2008-12-02   Albury      7.4  ...         No      0.0            No
# 2  2008-12-03   Albury     12.9  ...         No      0.0            No
# 3  2008-12-04   Albury      9.2  ...         No      1.0            No
# 4  2008-12-05   Albury     17.5  ...         No      0.2            No
#
# [5 rows x 24 columns]

# %%
# 5.
a['MinTemp']
# Out:
# 0         13.4
# 1          7.4
# 2         12.9
# 3          9.2
# 4         17.5
#           ...
# 142188     3.5
# 142189     2.8
# 142190     3.6
# 142191     5.4
# 142192     7.8
# Name: MinTemp, Length: 142193, dtype: float64

# %%
# 6.
a['WindGustSpeed'].max()
# Out:
# 135.0

# %%
# 7.
a['WindDir9am'].mode()
# Out:
# 0    N
# dtype: object

# %%
import matplotlib.pyplot as plt
b=a['MaxTemp']
c=a['MinTemp']
plt.plot(b,color='b',label='line one',marker='o',markerfacecolor='b')
plt.plot(c,color='r',label='line two',marker='o',markerfacecolor='r')
plt.title('line plot')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.grid(True,color='k',linestyle='-.')
plt.show()

# %%
import matplotlib.pyplot as plt
e=a['MaxTemp']
f=a['Pressure9am']
plt.plot(e,color='b',label='line one',marker='o',markerfacecolor='b')
plt.plot(f,color='r',label='line two',marker='o',markerfacecolor='r')
plt.title('line plot')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.grid(True,color='k',linestyle='-.')
plt.show()

# %% [markdown]
# # Group numbers are:
#
#
# *  A.pavan sri sai
#
# * j.ajay
#
# *  B.sujith kumar
# *   I.balaji
